# %% [markdown]
# <a href="https://colab.research.google.com/github/EcheverriaLuciano/Hello-Worl.py/blob/main/Codigospy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing_extensions import final
data_invalida = True
while (data_invalida):
   data_invalida = False
Data = input('Digite a data: ')
dia, mes, ano = Data.split('/')
dia = int(dia)
mes = int(mes)
ano = int(ano)

if (dia < 1 or dia > 31):
  print("Data invalida seu jaguara")
  data_invalida = True

if (mes < 1 or mes > 12):
  print("Data invalida seu jaguara")
  data_invalida = True

if (ano < 1900 or ano > 2026):
  print("Data invalida seu jaguara")
  data_invalida = True

print(f"sua data é = {Data}")
# Out:
# Digite a data: 08/09/2005
# sua data é = 08/09/2005

# %%
cpf_invalido = True
 while(cpf_invalido):
  cpf_invalido = False
cpf = int(input('Digite o cpf: '))
if (len(cpf) == 11) and (cpf[0] != '0')
    cpf_invalido = False
break
 print('CPF inválido')

# %%
nome_invalido = True
while (nome_invalido)
 nome_invalido = False
nome_completo = input('Qual seu nome completo? ')
primeiro_nome, segundo_nome = Data.split(' ')
primeiro_nome = str(primeiro_nome)
segundo_nome = str(segundo_nome)

# %%
frase = input('digite algo ')
print('A frase tem ', len(frase), 'caracteres')
print('A frase original', frase)
print('A frase em maiusculo', frase.upper())
print('A frase em minusculo', frase.lower())

frase = frase.replace('a', '@').replace('e', '&')
print('A frase modificada', frase)
# Out:
# digite algo nos somos estes infantes cujos peitos amantes nunca temem lutar
# A frase tem  63 caracteres
# A frase original nos somos estes infantes cujos peitos amantes nunca temem lutar
# A frase em maiusculo NOS SOMOS ESTES INFANTES CUJOS PEITOS AMANTES NUNCA TEMEM LUTAR
# A frase em minusculo nos somos estes infantes cujos peitos amantes nunca temem lutar
# A frase modificada nos somos &st&s inf@nt&s cujos p&itos @m@nt&s nunc@ t&m&m lut@r
